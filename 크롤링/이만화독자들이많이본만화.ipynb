# %%
import pandas as pd

# %%
# 필요 모듈 임포트
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup
import numpy as np

# %%
link = pd.read_csv('image_table.csv')

# %%
link.shape
# Out:
# (7503, 4)

# %%
link2 =pd.read_csv('old_image_table.csv')

# %%
link2.shape
# Out:
# (2890, 4)

# %%
origin = pd.concat([link, link2])

# %%
links = origin.page_link

# %%
url
# Out:
# 'https://comic.naver.com/webtoon/detail?titleId=719508&no=140&weekday=tue'

# %%
soup.find_all(class_='asideBox')
# Out:
# []

# %%
A = soup.find_all(class_='asideBox').copy()

# %%
print(A)
# Out:
# []

# %%
# 이미지 정보 테이블 작품명 / 이미지(각화 작품 썸네일 주소) / 제목(~화) / 각화 주소
mostview_table = origin.copy()
recommend = []
for link in links:
    url = link
    request = Request(url)
    request.get_method = lambda: 'GET'
    response_body = urlopen(request).read()
    soup = BeautifulSoup(response_body, 'html.parser')
    if soup.find_all(class_='asideBox') == A:
        recommend.append('[]')
    else :
        recommend.append(soup.find_all(class_='asideBox')[-1])

mostview_table['recommend'] = recommend

# %%
print(mostview_table.recommend.values[0])
# Out:
# []

# %%
mostview = mostview_table.reset_index(drop = True)

# %%
print('[]')
# Out:
# []

# %%
mostview['recommend'].dtypes
# Out:
# dtype('O')

# %%
mostview.to_csv('mostview.csv',index=False)

# %%
A = mostview['recommend'].values[0]

# %%
url = 'https://comic.naver.com/webtoon/detail?titleId=677740&no=5&weekday=tue'

# %%
url
# Out:
# 'https://comic.naver.com/webtoon/detail?titleId=758037&no=42&weekday=mon'

# %%
request = Request(url)
request.get_method = lambda: 'GET'
response_body = urlopen(request).read()
soup = BeautifulSoup(response_body, 'html.parser')

# %%
soup.find_all(class_='asideBox')[-1]
# Out:
# <div class="asideBox">
# <h4 class="asideBoxTitle">
# <img alt="이 만화 독자들이 많이 본 만화" class="tit_favoriteview" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/detail/subtlt_r_favoriteview.gif" title="이 만화 독자들이 많이 본 만화" width="145"/>
# </h4>
# <div class="favoriteview">
# <ol class="asideBoxRank">
# <li class="rank01">
# <div class="thumb6">
# <a href="/webtoon/list?titleId=670144" onclick="nclk_v2(event,'als.thum','','1')" title="가담항설">
# <img alt="가담항설" height="33" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/670144/thumbnail/title_thumbnail_20151230192753_t83x90.jpg" title="가담항설" width="30"/>
# <span class="mask"></span>
# </a>
# </div>
# ...

# %%
soup.select('#aside>div:nth-child(2)' )
# Out:
# [<div class="asideBox">
#  <h4 class="asideBoxTitle">
#  <img alt="이 만화 독자들이 많이 본 만화" class="tit_favoriteview" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/detail/subtlt_r_favoriteview.gif" title="이 만화 독자들이 많이 본 만화" width="145"/>
#  </h4>
#  <div class="favoriteview">
#  <ol class="asideBoxRank">
#  <li class="rank01">
#  <div class="thumb6">
#  <a href="/webtoon/list?titleId=670144" onclick="nclk_v2(event,'als.thum','','1')" title="가담항설">
#  <img alt="가담항설" height="33" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/670144/thumbnail/title_thumbnail_20151230192753_t83x90.jpg" title="가담항설" width="30"/>
#  <span class="mask"></span>
#  </a>
#  </div>
# ...

# %%
soup.select('#aside > div:nth-child(5) > div > ol')
# Out:
# [<ol class="asideBoxRank">
#  <li class="rank01">
#  <div class="thumb6">
#  <a href="/webtoon/list?titleId=651673" onclick="nclk_v2(event,'als.thum','','1')" title="[드라마원작] 유미의 세포들">
#  <img alt="[드라마원작] 유미의 세포들" height="33" onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" src="https://shared-comic.pstatic.net/thumb/webtoon/651673/thumbnail/thumbnail_IMAG10_659b9446-0940-494a-bb5f-5893290a84d0.jpg" title="[드라마원작] 유미의 세포들" width="30"/>
#  <span class="mask"></span>
#  </a>
#  </div>
#  <div class="rc_info rc_w"><a class="tit" href="/webtoon/list?titleId=651673" onclick="nclk_v2(event,'als.title','','1')" title="[드라마원작] 유미의 세포들">[드라마원작] 유미의 세포...</a><em><a href="#" onclick="nclk_v2(event,'als.artist','','1'); return artistAction.viewArtist('651673', this);" title="이동건">이동건</a></em></div>
#  </li>
#  <li class="rank02">
#  <div class="thumb6">
#  <a href="/webtoon/list?titleId=650304" onclick="nclk_v2(event,'als.thum','','2')" title="슈퍼 시크릿">
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ko">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <title>
#    투명한 동거 :: 네이버 만화
#   </title>
#   <meta content="투명한 동거 - 5화 회복기" property="og:title"/>
#   <meta content="https://shared-comic.pstatic.net/thumb/webtoon/677740/5/inst_thumbnail_nvme_20160516175227.jpg" property="og:image"/>
#   <meta content="5화 회복기" property="og:description"/>
#   <meta content="https://comic.naver.com/webtoon/detail?titleId=677740&amp;no=5&amp;weekday=tue" property="og:url"/>
#   <meta content="article" property="og:type"/>
#   <meta content="네이버 웹툰" property="og:article:author"/>
#   <meta content="https://comic.naver.com" property="og:article:author:url"/>
#   <link href="https://ssl.pstatic.net/static/comic/favicon/webtoon_favicon_32x32.ico" rel="shortcut icon" type="image/x-icon"/>
#   <script type="text/javascript">
#    document.domain = "naver.com";
#   </script>
# ...

# %%
most = pd.read_csv('mostview.csv')

# %%
mostview_table = most.loc[~(most.recommend=='[]')]

# %%
mostview_table
# Out:
#            name                                         page_image title  \
# 0           참교육  https://shared-comic.pstatic.net/thumb/webtoon...   42화
# 1           참교육  https://shared-comic.pstatic.net/thumb/webtoon...   41화
# 2           참교육  https://shared-comic.pstatic.net/thumb/webtoon...   40화
# 3           참교육  https://shared-comic.pstatic.net/thumb/webtoon...   39화
# 4           참교육  https://shared-comic.pstatic.net/thumb/webtoon...   38화
# ...         ...                                                ...   ...
# 10388  니나의 마법서랍  https://shared-comic.pstatic.net/thumb/webtoon...    6화
# 10389  니나의 마법서랍  https://shared-comic.pstatic.net/thumb/webtoon...    7화
# 10390  니나의 마법서랍  https://shared-comic.pstatic.net/thumb/webtoon...    8화
# 10391  니나의 마법서랍  https://shared-comic.pstatic.net/thumb/webtoon...    9화
# 10392  니나의 마법서랍  https://shared-comic.pstatic.net/thumb/webtoon...   10화
#
#                                                page_link  \
# ...

# %%
loss = mostview_table.name.unique()

# %%
print(loss)
# Out:
# ['헬58' '헬퍼 2 : 킬베로스' '포식동물' '스퍼맨 : 전하지 못한 이야기' '압락사스' '벚꽃이 흩날릴 무렵']

# %%
mostview_table.reset_index(drop=True).to_csv('mostview_table.csv',index=False)

# %%
most = pd.read_csv('mostview_table.csv')

# %%
mostview_table = most.copy()

# %%
mostview_table.drop(mostview_table.loc[mostview_table['recommend']=='<div class="asideBox">\n<h4 class="asideBoxTitle"><img alt="인기급상승만화" height="11" src="https://ssl.pstatic.net/static/comic/images/migration/common/subtlt_r_best.gif" title="인기급상승만화" width="78"/></h4>\n<div>\n<ul class="asideBoxTab"><!-- 선택된 메뉴에는 choice라는 클래스명을 사용합니다 -->\n<li class="choice" id="realTimeRankChoiceTabFavorite"><a href="#" id="realTimeRankChoiceTabFavoriteClick" onclick="nclk_v2(event,\'rnk.rep\')"><img alt="인기순" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/common/tab_txt_favor.gif" title="인기순" width="31"/></a></li>\n<li id="realTimeRankChoiceTabUpdate"><a href="#" id="realTimeRankChoiceTabUpdateClick" onclick="nclk_v2(event,\'rnk.upd\')"><img alt="업데이트순" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/common/tab_txt_update.gif" title="업데이트순" width="52"/></a></li>\n</ul>\n<h3 class="blind" id="realTimeRankBlindName">인기순</h3>\n<ol class="asideBoxRank" id="realTimeRankFavorite">\n<li class="rank01">\n<a href="/webtoon/detail?titleId=570503&amp;no=370" onclick="nclk_v2(event,\'rnk*p.cont\',\'570503\',\'1\')" title="연애혁명-366. Focusing">연애혁명-366. Focusing</a>\n<span class="rankBox">\n<img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0\n\t\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t</span>\n</li>\n<li class="rank02">\n<a href="/webtoon/detail?titleId=736989&amp;no=94" onclick="nclk_v2(event,\'rnk*p.cont\',\'736989\',\'2\')" title="더 복서-89화 우상">더 복서-89화 우상</a>\n<span class="rankBox">\n<img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0\n\t\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t</span>\n</li>\n<li class="rank03">\n<a href="/webtoon/detail?titleId=748105&amp;no=103" onclick="nclk_v2(event,\'rnk*p.cont\',\'748105\',\'3\')" title="독립일기-시즌2 예고편 ">독립일기-시즌2 예고편</a>\n<span class="rankBox">\n<img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0\n\t\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t</span>\n</li>\n<li class="rank04">\n<a href="/webtoon/detail?titleId=756137&amp;no=43" onclick="nclk_v2(event,\'rnk*p.cont\',\'756137\',\'4\')" title="노답소녀-43화">노답소녀-43화</a>\n<span class="rankBox">\n<img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0\n\t\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t</span>\n</li>\n<li class="rank05">\n<a href="/webtoon/detail?titleId=731130&amp;no=110" onclick="nclk_v2(event,\'rnk*p.cont\',\'731130\',\'5\')" title="이두나!-106화. 이원준의 취중진담 (4)">이두나!-106화. 이원준의 취중진담 (4)</a>\n<span class="rankBox">\n<img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0\n\t\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t</span>\n</li>\n<li class="rank06">\n<a href="/webtoon/detail?titleId=762279&amp;no=36" onclick="nclk_v2(event,\'rnk*p.cont\',\'762279\',\'6\')" title="정글쥬스-36화">정글쥬스-36화</a>\n<span class="rankBox">\n<img alt="순위상승" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_up.gif" title="순위상승" width="7"/>2\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t</span>\n</li>\n<li class="rank07">\n<a href="/webtoon/detail?titleId=557672&amp;no=364" onclick="nclk_v2(event,\'rnk*p.cont\',\'557672\',\'7\')" title="기기괴괴-343화 기름충 다이어트 #1">기기괴괴-343화 기름충 다이어트 #1</a>\n<span class="rankBox">\n<img alt="순위하락" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_down.gif" title="순위하락" width="7"/>1\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t</span>\n</li>\n<li class="rank08">\n<a href="/webtoon/detail?titleId=747271&amp;no=64" onclick="nclk_v2(event,\'rnk*p.cont\',\'747271\',\'8\')" title="나노마신-064. 제25장. 위험한 삼 단계 시험 (1)">나노마신-064. 제25장. 위험한 삼 단계 시험 (1)</a>\n<span class="rankBox">\n<img alt="순위하락" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_down.gif" title="순위하락" width="7"/>1\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t</span>\n</li>\n<li class="rank09">\n<a href="/webtoon/detail?titleId=758659&amp;no=5" onclick="nclk_v2(event,\'rnk*p.cont\',\'758659\',\'9\')" title="오빠세끼-#5 발렌타인의 저주">오빠세끼-#5 발렌타인의 저주</a>\n<span class="rankBox">\n<img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0\n\t\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t</span>\n</li>\n<li class="rank10">\n<a href="/webtoon/detail?titleId=775218&amp;no=10" onclick="nclk_v2(event,\'rnk*p.cont\',\'775218\',\'10\')" title="묵시의 인플루언서-10화">묵시의 인플루언서-10화</a>\n<span class="rankBox">\n<img alt="변동없음" height="10" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" width="7"/> 0\n\t\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t</span>\n</li>\n</ol>\n<ol class="asideBoxRank" id="realTimeRankUpdate" style="display:none;">\n<li class="rank01">\n<a href="/webtoon/detail?titleId=716857&amp;no=380" onclick="nclk_v2(event,\'rnk*u.cont\',\'716857\',\'1\')" title="오늘의 순정망화-시즌2 196화">\n\t\t\t\t\t\n\t\t\t\t\t오늘의 순정망화-시즌2 196화\n\t\t\t\t</a>\n<span class="timeBox">\n\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\t19시간전\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t</span>\n</li>\n<li class="rank02">\n<a href="/webtoon/detail?titleId=570503&amp;no=370" onclick="nclk_v2(event,\'rnk*u.cont\',\'570503\',\'2\')" title="연애혁명-366. Focusing">\n\t\t\t\t\t\n\t\t\t\t\t연애혁명-366. Focusing\n\t\t\t\t</a>\n<span class="timeBox">\n\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\t19시간전\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t</span>\n</li>\n<li class="rank03">\n<a href="/webtoon/detail?titleId=715935&amp;no=149" onclick="nclk_v2(event,\'rnk*u.cont\',\'715935\',\'3\')" title="롤랑롤랑-146화">\n\t\t\t\t\t\n\t\t\t\t\t롤랑롤랑-146화\n\t\t\t\t</a>\n<span class="timeBox">\n\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\t19시간전\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t</span>\n</li>\n<li class="rank04">\n<a href="/webtoon/detail?titleId=731130&amp;no=110" onclick="nclk_v2(event,\'rnk*u.cont\',\'731130\',\'4\')" title="이두나!-106화. 이원준의 취중진담 (4)">\n\t\t\t\t\t\n\t\t\t\t\t이두나!-106화. 이원준의 취중진담 (4)\n\t\t\t\t</a>\n<span class="timeBox">\n\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\t19시간전\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t</span>\n</li>\n<li class="rank05">\n<a href="/webtoon/detail?titleId=731930&amp;no=89" onclick="nclk_v2(event,\'rnk*u.cont\',\'731930\',\'5\')" title="안개무덤-89화 정내천의 거울 (3)">\n\t\t\t\t\t\n\t\t\t\t\t안개무덤-89화 정내천의 거울 (3)\n\t\t\t\t</a>\n<span class="timeBox">\n\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\t19시간전\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t</span>\n</li>\n<li class="rank06">\n<a href="/webtoon/detail?titleId=740487&amp;no=71" onclick="nclk_v2(event,\'rnk*u.cont\',\'740487\',\'6\')" title="신비-70화">\n\t\t\t\t\t\n\t\t\t\t\t신비-70화\n\t\t\t\t</a>\n<span class="timeBox">\n\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\t19시간전\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t</span>\n</li>\n<li class="rank07">\n<a href="/webtoon/detail?titleId=768534&amp;no=48" onclick="nclk_v2(event,\'rnk*u.cont\',\'768534\',\'7\')" title="수영만화일기-46화 수영용품 관리">\n\t\t\t\t\t\n\t\t\t\t\t수영만화일기-46화 수영용품 관리\n\t\t\t\t</a>\n<span class="timeBox">\n\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\t19시간전\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t</span>\n</li>\n<li class="rank08">\n<a href="/webtoon/detail?titleId=131385&amp;no=520" onclick="nclk_v2(event,\'rnk*u.cont\',\'131385\',\'8\')" title="쿠베라-3부 214화 아난타 (3)">\n\t\t\t\t\t\n\t\t\t\t\t쿠베라-3부 214화 아난타 (3)\n\t\t\t\t</a>\n<span class="timeBox">\n\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\t19시간전\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t</span>\n</li>\n<li class="rank09">\n<a href="/webtoon/detail?titleId=570506&amp;no=416" onclick="nclk_v2(event,\'rnk*u.cont\',\'570506\',\'9\')" title="최강전설 강해효-414화">\n\t\t\t\t\t\n\t\t\t\t\t최강전설 강해효-414화\n\t\t\t\t</a>\n<span class="timeBox">\n\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\t19시간전\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t</span>\n</li>\n<li class="rank10">\n<a href="/webtoon/detail?titleId=710761&amp;no=163" onclick="nclk_v2(event,\'rnk*u.cont\',\'710761\',\'10\')" title="하드캐리-163. 방출">\n\t\t\t\t\t\n\t\t\t\t\t하드캐리-163. 방출\n\t\t\t\t</a>\n<span class="timeBox">\n\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\t19시간전\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t</span>\n</li>\n</ol>\n</div>\n</div>'].index, inplace= True)

# %%
most.groupby('recommend').count().index.values[-16]
# Out:
# '<div class="asideBox">\n<h4 class="asideBoxTitle">\n<img alt="이 만화 독자들이 많이 본 만화" class="tit_favoriteview" height="12" src="https://ssl.pstatic.net/static/comic/images/migration/detail/subtlt_r_favoriteview.gif" title="이 만화 독자들이 많이 본 만화" width="145"/>\n</h4>\n<div class="favoriteview">\n<ol class="asideBoxRank">\n<li class="rank01">\n<div class="thumb6">\n<a href="/webtoon/list?titleId=769568" onclick="nclk_v2(event,\'als.thum\',\'\',\'1\')" title="반드시 해피엔딩">\n<img alt="반드시 해피엔딩" height="33" onerror="this.src=\'https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif\'" src="https://shared-comic.pstatic.net/thumb/webtoon/769568/thumbnail/thumbnail_IMAG10_7fc6c51f-7e8b-4c42-92e6-a2106b95a97d.jpg" title="반드시 해피엔딩" width="30"/>\n<span class="mask"></span>\n</a>\n</div>\n<div class="rc_info rc_w"><a class="tit" href="/webtoon/list?titleId=769568" onclick="nclk_v2(event,\'als.title\',\'\',\'1\')" title="반드시 해피엔딩">반드시 해피엔딩</a><em><a href="#" onclick="nclk_v2(event,\'als.artis
# ...

# %%
mostview_table
# Out:
#            name                                         page_image   title  \
# 20         신의 탑  https://shared-comic.pstatic.net/thumb/webtoon...  3부 82화
# 21         신의 탑  https://shared-comic.pstatic.net/thumb/webtoon...  3부 81화
# 22         신의 탑  https://shared-comic.pstatic.net/thumb/webtoon...  3부 80화
# 23         신의 탑  https://shared-comic.pstatic.net/thumb/webtoon...  3부 79화
# 24         신의 탑  https://shared-comic.pstatic.net/thumb/webtoon...  3부 78화
# ...         ...                                                ...     ...
# 10250  니나의 마법서랍  https://shared-comic.pstatic.net/thumb/webtoon...      6화
# 10251  니나의 마법서랍  https://shared-comic.pstatic.net/thumb/webtoon...      7화
# 10252  니나의 마법서랍  https://shared-comic.pstatic.net/thumb/webtoon...      8화
# 10253  니나의 마법서랍  https://shared-comic.pstatic.net/thumb/webtoon...      9화
# 10254  니나의 마법서랍  https://shared-comic.pstatic.net/thumb/webtoon...     10화
#
#                                                page_link  \
# ...

# %%
mostview_table.groupby('recommend').count().sort_values('name')
# Out:
#                                                     name  page_image  title  \
# recommend
# <div class="asideBox">\n<h4 class="asideBoxTitl...     1           1      1
# <div class="asideBox">\n<h4 class="asideBoxTitl...     1           1      1
# <div class="asideBox">\n<h4 class="asideBoxTitl...     1           1      1
# <div class="asideBox">\n<h4 class="asideBoxTitl...     1           1      1
# <div class="asideBox">\n<h4 class="asideBoxTitl...     2           2      2
# ...                                                  ...         ...    ...
# <div class="asideBox">\n<h4 class="asideBoxTitl...    30          30     30
# <div class="asideBox">\n<h4 class="asideBoxTitl...    60          60     60
# <div class="asideBox">\n<h4 class="asideBoxTitl...    60          60     60
# <div class="asideBox">\n<h4 class="asideBoxTitl...    60          60     60
# <div class="asideBox">\n<h4 class="asideBoxTitl...    60          60     60
#
# ...

# %%
result = []
for i in mostview_table.recommend.values:
    temp_result = []
    for j in np.arange(len(BeautifulSoup(i, 'html.parser').find_all('a', class_='tit'))):
        temp_result.append(BeautifulSoup(i, 'html.parser').find_all('a', class_='tit')[j].get('title'))
    result.append(temp_result)

# %%
BeautifulSoup(mostview_table.recommend.values[0], 'html.parser').find_all('a', class_='tit')
# Out:
# [<a class="tit" href="/webtoon/list?titleId=670152" onclick="nclk_v2(event,'als.title','','1')" title="열렙전사">열렙전사</a>,
#  <a class="tit" href="/webtoon/list?titleId=318995" onclick="nclk_v2(event,'als.title','','2')" title="갓 오브 하이스쿨">갓 오브 하이스쿨</a>,
#  <a class="tit" href="/webtoon/list?titleId=714185" onclick="nclk_v2(event,'als.title','','3')" title="링크보이">링크보이</a>,
#  <a class="tit" href="/webtoon/list?titleId=316909" onclick="nclk_v2(event,'als.title','','4')" title="그 판타지 세계에서 사는 법">그 판타지 세계에서 사는 ...</a>,
#  <a class="tit" href="/webtoon/list?titleId=25455" onclick="nclk_v2(event,'als.title','','5')" title="노블레스">노블레스</a>]

# %%
result
# Out:
# [['열렙전사', '갓 오브 하이스쿨', '링크보이', '그 판타지 세계에서 사는 법', '노블레스'],
#  ['열렙전사', '갓 오브 하이스쿨', '링크보이', '그 판타지 세계에서 사는 법', '노블레스']]

# %%
mostview_table['result'] = result

# %%
mostview_table = mostview_table[['name','title','result']]

# %%
mostview_table.to_csv('mostview_table_result.csv',index=False)

# %%
result = pd.read_csv('mostview_table_result.csv').result.str.split(',',expand = True)

# %%
result[0]= result[0].str.replace('[','')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-149-37f9e48eb3e6> in <module>
# ...

# %%
for i in result.columns:
    result[i]= result[i].str.replace('[','')
# Out:
# <ipython-input-158-e8f4810b79fe>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   result[i]= result[i].str.replace('[','')

# %%
for i in result.columns:
    result[i]= result[i].str.replace(']','')
# Out:
# <ipython-input-159-5d60df6b2a41>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   result[i]= result[i].str.replace(']','')

# %%
for i in result.columns:
    result[i]= result[i].str.replace('드라마원작','[드라마원작]')

# %%
result.columns = ['1순위 추천', '2순위 추천', '3순위 추천', '4순위 추천', '5순위 추천','error']

# %%
result.to_csv('recommend_rank.csv',index=False)

# %%
pd.read_csv('recommend_rank.csv',sep=';')
# Out:
#       1순위 추천        2순위 추천     3순위 추천              4순위 추천    5순위 추천  \
# 0     '열렙전사'   '갓 오브 하이스쿨'     '링크보이'   '그 판타지 세계에서 사는 법'    '노블레스'
# 1     '열렙전사'   '갓 오브 하이스쿨'     '링크보이'   '그 판타지 세계에서 사는 법'    '노블레스'
# 2     '열렙전사'   '갓 오브 하이스쿨'     '링크보이'   '그 판타지 세계에서 사는 법'    '노블레스'
# 3     '열렙전사'   '갓 오브 하이스쿨'     '링크보이'   '그 판타지 세계에서 사는 법'    '노블레스'
# 4     '열렙전사'   '갓 오브 하이스쿨'     '링크보이'   '그 판타지 세계에서 사는 법'    '노블레스'
# ...      ...           ...        ...                 ...       ...
# 6142  '가담항설'     'SM 플레이어'   '악당의 사연'             '요리대마왕'   '야! 오이'
# 6143  '가담항설'     'SM 플레이어'   '악당의 사연'             '요리대마왕'   '야! 오이'
# 6144  '가담항설'     'SM 플레이어'   '악당의 사연'             '요리대마왕'   '야! 오이'
# 6145  '가담항설'     'SM 플레이어'   '악당의 사연'             '요리대마왕'   '야! 오이'
# 6146  '가담항설'     'SM 플레이어'   '악당의 사연'             '요리대마왕'   '야! 오이'
#
#       Unnamed: 5
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 6142         NaN
# ...

# %%
pd.read_csv('recommend_rank.csv',sep=';').iloc[:,:5].to_csv('recommend_rank.csv',index=False,sep=';')

# %%
pd.read_csv('recommend_rank.csv',sep=';')
# Out:
#       1순위 추천        2순위 추천     3순위 추천              4순위 추천    5순위 추천
# 0     '열렙전사'   '갓 오브 하이스쿨'     '링크보이'   '그 판타지 세계에서 사는 법'    '노블레스'
# 1     '열렙전사'   '갓 오브 하이스쿨'     '링크보이'   '그 판타지 세계에서 사는 법'    '노블레스'
# 2     '열렙전사'   '갓 오브 하이스쿨'     '링크보이'   '그 판타지 세계에서 사는 법'    '노블레스'
# 3     '열렙전사'   '갓 오브 하이스쿨'     '링크보이'   '그 판타지 세계에서 사는 법'    '노블레스'
# 4     '열렙전사'   '갓 오브 하이스쿨'     '링크보이'   '그 판타지 세계에서 사는 법'    '노블레스'
# ...      ...           ...        ...                 ...       ...
# 6142  '가담항설'     'SM 플레이어'   '악당의 사연'             '요리대마왕'   '야! 오이'
# 6143  '가담항설'     'SM 플레이어'   '악당의 사연'             '요리대마왕'   '야! 오이'
# 6144  '가담항설'     'SM 플레이어'   '악당의 사연'             '요리대마왕'   '야! 오이'
# 6145  '가담항설'     'SM 플레이어'   '악당의 사연'             '요리대마왕'   '야! 오이'
# 6146  '가담항설'     'SM 플레이어'   '악당의 사연'             '요리대마왕'   '야! 오이'
#
# [6147 rows x 5 columns]

# %%
left= pd.read_csv('mostview_table_result.csv').iloc[:,:2]

# %%
right = pd.read_csv('recommend_rank.csv',sep=';')

# %%
pd.concat([left, right],axis=1).to_csv('recommend_table.csv',sep=';',index=False)

# %%
pd.read_csv('recommend_rank.csv',sep=';').groupby('5순위 추천').count()
# Out:
#                      1순위 추천  2순위 추천  3순위 추천  4순위 추천
# 5순위 추천
#  '3P'                    30      30      30      30
#  'MZ'                     5       5       5       5
#  '가비지타임'                 17      17      17      17
#  '각자의 디데이'               22      22      22      22
#  '격기3반'                  30      30      30      30
#  '고수'                    66      66      66      66
#  '곱게 키웠더니, 짐승'           12      12      12      12
#  '그들이 사귀는 세상'             6       6       6       6
#  '금혼령-조선혼인금지령'           12      12      12      12
#  '노블레스'                  60      60      60      60
#  '닥터 프로스트 시즌 1~2'        30      30      30      30
#  '달수 이야기'                30      30      30      30
#  '달콤한 인생'                30      30      30      30
#  '리턴 투 플레이어'              5       5       5       5
#  '머니게임'                  18      18      18      18
#  '바른연애 길잡이'              30      30      30      30
#  '부활남'                   30      30      30      30
# ...

# %%
pd.read_csv('recommend_table.csv',sep=';').drop(columns='title').drop_duplicates().to_csv('recommend_table_noduplication.csv',sep=';',index=False)
